# %%
#bad_words = ['WARNING: Fix qeq/reax CG convergence']
#for i in range(11):
    #with open('/Users/rajesh/work/github/helloword/cash_min_relax/'+str(i+1)) as oldfile, open('/Users/rajesh/work/github/helloword/cash_min_relax/'+(str)(i+1)+str(i+1), 'w') as newfile:
       # for line in oldfile:
           # if not any(bad_word in line for bad_word in bad_words):
                #newfile.write(line)

# %%
import sys
sys.path.append("/Users/rajesh/work/github/python_packages")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
import lmps.log as log
data=[]
fig, ax = plt.subplots()
for i in range(10):
    
    tables=[]
    tables = np.loadtxt('/Users/rajesh/work/github/helloword/cash_min_relax/'+str(i+1)+str(i+1),skiprows=195,dtype = float)
    
    type(tables)
    
    #print(tables[:,0])
    data.append(tables)
    #print(data[i][:,0])
    plt.plot(data[i][:,0], data[i][:,1], linewidth=2.0,label='Z_'+str(int(data[i][-1,-1])))
    plt.xscale('log',basex=10)
    plt.legend(loc='upper right')
    plt.xlabel('Steps')
    plt.ylabel('Atoms')
plt.show()
#ax.legend()
fig.savefig('Cash_ATOM'+str(i)+'.png',format=None,dpi=300,bbox_inches="tight")


    #ax.plot(data[i][0,:],data[i][1,:],label=str(i))

# %%
import sys
sys.path.append("/Users/rajesh/work/github/python_packages")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
import lmps.log as log
data=[]
fig, ax = plt.subplots()
for i in range(10):
    
    tables=[]
    tables = np.loadtxt('/Users/rajesh/work/github/helloword/cash_min_relax/'+str(i+1)+str(i+1),skiprows=195,dtype = float)
    
    type(tables)
    
    #print(tables[:,0])
    data.append(tables)
    #print(data[i][:,0])
    plt.plot(data[i][:,0], data[i][:,2], linewidth=2.0,label='Z_'+str(int(data[i][-1,-1])))
    plt.xscale('log',basex=10)
    plt.legend(loc='lower left')
    plt.xlabel('Steps')
    plt.ylabel('PotEng ')
plt.show()
#ax.legend()
fig.savefig('Cash_PotEng'+str(i)+'.png',format=None,dpi=300,bbox_inches="tight")


    #ax.plot(data[i][0,:],data[i][1,:],label=str(i))

# %%
import sys
sys.path.append("/Users/rajesh/work/github/python_packages")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
import lmps.log as log
data=[]
fig, ax = plt.subplots()
for i in range(10):
    
    tables=[]
    tables = np.loadtxt('/Users/rajesh/work/github/helloword/cash_min_relax/'+str(i+1)+str(i+1),skiprows=195,dtype = float)
    
    type(tables)
    
    #print(tables[:,0])
    data.append(tables)
    #print(data[i][:,0])
    plt.plot(data[i][:,0], data[i][:,5], linewidth=2.0,label='Z_'+str(int(data[i][-1,-1])))
    plt.xscale('log',basex=10)
    plt.legend(loc='lower left')
    plt.xlabel('Steps')
    plt.ylabel('Press ')
plt.show()
#ax.legend()
fig.savefig('Cash_Press '+str(i)+'.png',format=None,dpi=300,bbox_inches="tight")


    #ax.plot(data[i][0,:],data[i][1,:],label=str(i))

# %%
import sys
sys.path.append("/Users/rajesh/work/github/python_packages")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
import lmps.log as log
data=[]
fig, ax = plt.subplots()
for i in range(10):
    
    tables=[]
    tables = np.loadtxt('/Users/rajesh/work/github/helloword/cash_min_relax/'+str(i+1)+str(i+1),skiprows=195,dtype = float)
    
    type(tables)
    
    #print(tables[:,0])
    data.append(tables)
    #print(data[i][:,0])
    plt.plot(data[i][:,0], data[i][:,5], linewidth=2.0,label='Z_'+str(int(data[i][-1,-1])))
    plt.xscale('log',basex=10)
    plt.legend(loc='lower left')
    plt.xlabel('Steps')
    plt.ylabel('Press ')
    plt.show()
#ax.legend()
#fig.savefig('Cash_Press '+str(i)+'.png',format=None,dpi=300,bbox_inches="tight")


    #ax.plot(data[i][0,:],data[i][1,:],label=str(i))

# %%
print(data[0])
# Out:
# [[ 1.3000000e+02  1.6700000e+02 -2.2227728e+04  2.1884557e+03
#    2.4865587e+00 -1.4602048e+04  2.3881629e-01  0.0000000e+00
#    8.9997090e+00]
#  [ 1.4000000e+02  1.6700000e+02 -2.2227728e+04  2.1884557e+03
#    2.4865587e+00 -1.4601580e+04  2.3881629e-01  0.0000000e+00
#    8.9997090e+00]
#  [ 1.5000000e+02  1.7000000e+02 -2.2311666e+04  2.1884557e+03
#    2.5002282e+00  5.5433452e+04  9.2751203e-01  0.0000000e+00
#    8.9997090e+00]
#  [ 1.6000000e+02  1.6700000e+02 -2.2227728e+04  2.1884557e+03
#    2.4865587e+00 -1.4601995e+04  2.3881629e-01  0.0000000e+00
#    8.9997090e+00]
#  [ 1.7000000e+02  1.6700000e+02 -2.2227728e+04  2.1884557e+03
#    2.4865587e+00 -1.4602336e+04  2.3881629e-01  0.0000000e+00
#    8.9997090e+00]
#  [ 1.8000000e+02  1.6700000e+02 -2.2227728e+04  2.1884557e+03
#    2.4865587e+00 -1.4601608e+04  2.3881629e-01  0.0000000e+00
#    8.9997090e+00]
#  [ 1.9000000e+02  1.7000000e+02 -2.2352246e+04  2.1884557e+03
#    2.5002282e+00 -3.9166198e+03  5.8842005e-01  0.0000000e+00
#    8.9997090e+00]
#  [ 2.0000000e+02  1.6700000e+02 -2.2227728e+04  2.1884557e+03
#    2.4865587e+00 -1.4601964e+04  2.3881629e-01  0.0000000e+00
#    8.9997090e+00]
#  [ 2.1000000e+02  1.6700000e+02 -2.2227728e+04  2.1884557e+03
#    2.4865587e+00 -1.4602196e+04  2.3881629e-01  0.0000000e+00
#    8.9997090e+00]
#  [ 2.2000000e+02  1.7000000e+02 -2.2434942e+04  2.1884557e+03
#    2.5002282e+00  1.0764567e+04  3.6529429e+00  0.0000000e+00
#    8.9997090e+00]
#  [ 2.3000000e+02  1.7300000e+02 -2.2644623e+04  2.1884557e+03
#    2.5138977e+00  1.3052102e+04  6.0089454e+00  0.0000000e+00
#    8.9997090e+00]
#  [ 2.4000000e+02  1.7300000e+02 -2.2644623e+04  2.1884557e+03
#    2.5138977e+00  1.3051426e+04  6.0089454e+00  0.0000000e+00
#    8.9997090e+00]
#  [ 2.5000000e+02  1.7300000e+02 -2.2645361e+04  2.1884557e+03
#    2.5138977e+00 -4.7084115e+03  3.4323470e+00  0.0000000e+00
#    8.9997090e+00]
#  [ 2.6000000e+02  1.7600000e+02 -2.2739922e+04  2.1884557e+03
#    2.5275672e+00  3.4752311e+04  7.5626437e+00  0.0000000e+00
#    8.9997090e+00]
#  [ 2.7000000e+02  1.7300000e+02 -2.2645361e+04  2.1884557e+03
#    2.5138977e+00 -4.7074890e+03  3.4323470e+00  0.0000000e+00
#    8.9997090e+00]
#  [