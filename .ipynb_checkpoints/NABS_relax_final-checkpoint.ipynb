# %%
##this script is to plot B4 and Density
#relax structue from full simulaton final data file
#'10 K/ps', '1 K/ps', '0.1 K/ps','100 K/ps' are [3,2,1,4]: respectivaly

#0.1 K/ps--> 3
#1 K/ps--> 2
#10 K/ps--> 1
#100 K/ps--> 4

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 

plt.rc('font', family='CMU Serif',)

matplotlib.rcParams['text.latex.preamble'] = [r'\boldmath']

EXP = np.loadtxt("NABS_EXP.txt")


fig, (ax1,ax2) = plt.subplots(2,1,figsize=[8,11])
data = []
names = []
df = []
ttl=['al0','al1','al2.5','al5','al7.5','al10','al12.5','al15','al17.5','al20']
leg=['10 K/ps', '1 K/ps', '0.1 K/ps','100 K/ps']
ax1.plot(ttl,EXP[:,2],label='EXP')
ax2.plot(ttl,EXP[:,5],label='EXP')

for i in [3,2,1,4]:
    b=[] 
    d=[]
    
    for j in range(1,11):
        if (i==4)&(j==7):
            b.append(b[-1])
            d.append(d[-1])
            #pass
        else:
            #print(i)
            foldername = '/Users/rajesh/work/simulations/cool_NABS_relax/relax10K/cool'+str(j)+'_'+str(i)
            filename = foldername +'/log.lammps'
            #print(filename)
            a = [181, 1, 190, 2]  
            #names.append(np.genfromtxt(filename, skip_header=a[0],max_rows=a[1],dtype=str))   
            #print(names)
            data.append(np.genfromtxt(filename, skip_header=a[2],max_rows=a[3],dtype=float))   
            #print(names[i-1])
            #print(data[i-1])
            #df.append(pd.DataFrame(data[i-1][-1]),columns=names[i-1][-1])
            bb=data[-1][-1][-1]
            dd=data[-1][-1][-2]
            b.append((bb-3)*100) #changed to array by .values
        
            d.append(dd)
                
                
                
                
    ax1.set_ylabel('B4')
    ax2.set_ylabel('Density')
    ax1.set_xlabel('Al %')
    ax2.set_xlabel('Al %')
   
    ax1.plot(ttl,b,label=str(leg[i-1]))
    
    ax2.plot(ttl,d,label=str(leg[i-1]))
ax1.legend()
ax2.legend()



fig.savefig('B4_vs_rex.eps',format=None,dpi=300,bbox_inches="tight")

# %%
data[-1][-1]
# Out:
# array([ 1.9000000e+04,  3.0118382e+02, -8.4733379e+05,  1.7177079e+03,
#         3.5924880e+01,  2.5432394e+00,  3.3909091e+00])

# %%
 data[-1][-1][-2]
a
# Out:
# array([[0.0000e+00, 7.7586e+01, 9.4900e+01, 5.0782e+00, 0.0000e+00,
#         2.3955e+00, 2.4120e+00, 1.3769e-02],
#        [1.0000e+00, 7.3276e+01, 9.3200e+01, 1.7876e+00, 1.0000e+00,
#         2.4194e+00, 2.4140e+00, 2.1387e-02],
#        [2.5000e+00, 6.7544e+01, 9.4600e+01, 2.1487e+00, 2.5000e+00,
#         2.4078e+00, 2.4090e+00, 1.9768e-02],
#        [2.0000e+00, 6.2500e+01, 9.1600e+01, 3.8610e+00, 5.0000e+00,
#         2.3961e+00, 2.4060e+00, 1.5482e-02],
#        [7.5000e+00, 5.1818e+01, 8.3100e+01, 3.8247e+00, 7.5000e+00,
#         2.4069e+00, 2.4020e+00, 1.7333e-02],
#        [3.0000e+00, 4.1818e+01, 7.4400e+01, 1.8631e+00, 1.0000e+01,
#         2.4038e+00, 2.3920e+00, 9.4679e-03],
#        [4.0000e+00, 3.6111e+01, 4.3600e+01, 6.3949e+00, 1.2500e+01,
#         2.3899e+00, 2.3980e+00, 7.0549e-03],
#        [5.0000e+00, 2.3585e+01, 1.9900e+01, 3.5923e+00, 1.5000e+01,
#         2.3850e+00, 2.3840e+00, 1.3199e-02],
#        [1.7500e+01, 1.6346e+01, 1.0000e+00, 2.9165e+00, 1.7500e+01,
#         2.3809e+00, 2.4000e+00, 1.1350e-02],
#        [6.0000e+00, 8.8235e+00, 8.0000e-01, 8.2025e-01, 2.0000e+01,
#         2.3687e+00, 2.4090e+00, 1.4275e-02]])

# %%
EXP = np.loadtxt("NABS_EXP.txt")

# %%
# Out:
# array([94.9, 93.2, 94.6, 91.6, 83.1, 74.4, 43.6, 19.9,  1. ,  0.8])

# %%
EXP[:,2]
# Out:
# array([94.9, 93.2, 94.6, 91.6, 83.1, 74.4, 43.6, 19.9,  1. ,  0.8])

# %%
EXP[:,5]
# Out:
# array([2.3955, 2.4194, 2.4078, 2.3961, 2.4069, 2.4038, 2.3899, 2.385 ,
#        2.3809, 2.3687])
